# %% [markdown]
# <a href="https://colab.research.google.com/github/ananth85/python/blob/main/text_to_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch

# Load the Stable Diffusion model
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipe = pipe.to("cuda" if torch.cuda.is_available() else "cpu")

def generate_image(prompt, output_path="generated_image.png"):
    image = pipe(prompt).images[0]  # Generate the image
    image.save(output_path)
    print(f"Image saved to {output_path}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# ...

# %%
user_prompt = input("Enter your prompt: ")
generate_image(user_prompt)
# Out:
# Enter your prompt: Dinosaurs without helmets dressed as astronauts fixing a space station in outer space. The space station appears futuristic with metallic textures, solar panels, and complex machinery. The dinosaurs are depicted as intelligent beings, using tools to make repairs. The backdrop shows a vast, starry cosmos with distant galaxies. The scene blends a sense of science fiction and humor.
#   0%|          | 0/50 [00:00<?, ?it/s]
# Image saved to generated_image.png

# %%
from IPython.display import Image
Image(filename='generated_image.png')

# %%
# !pip install diffusers transformers accelerate torch

# %%
# !pip install diffusers transformers accelerate torch

from diffusers import StableDiffusionPipeline
import torch

# Specify the model ID from Hugging Face
model_id = "runwayml/stable-diffusion-v1-5"

# Load the model pipeline
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")  # Use GPU if available

print("Stable Diffusion model downloaded and ready to use!")
# Out:
# ...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Stable Diffusion model downloaded and ready to use!

# %%
from diffusers import StableDiffusionPipeline, StableDiffusionTrainer
from transformers import AutoTokenizer
import torch

# Load model and tokenizer
model_id = "runwayml/stable-diffusion-v1-5"
tokenizer = AutoTokenizer.from_pretrained(model_id)
pipeline = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16).to("cuda")

# Fine-tuning setup
trainer = StableDiffusionTrainer(
    model=pipeline.unet,
    tokenizer=tokenizer,
    dataset_path="./your-dataset-path",  # Path to your image-text dataset
    resolution=512,
    batch_size=2,
    learning_rate=1e-4,
    max_train_steps=1000,
    output_dir="./fine-tuned-model"
)

# Train the model
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-eeabe30bd2ba> in <cell line: 0>()
# ----> 1 from diffusers import StableDiffusionPipeline, StableDiffusionTrainer
#       2 from transformers import AutoTokenizer
#       3 import torch
#       4
#       5 # Load model and tokenizer
#
# ImportError: cannot import name 'StableDiffusionTrainer' from 'diffusers' (/usr/local/lib/python3.11/dist-packages/diffusers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained("./fine-tuned-model", torch_dtype=torch.float16).to("cuda")
prompt = "Dinosaurs without helmets dressed as astronauts fixing a futuristic space station in outer space"
image = pipe(prompt).images[0]
image.show()
